# %% [markdown]
# <a href="https://colab.research.google.com/github/HyojinKim88/ML-for-AI/blob/main/week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition
# Out:
# /content/drive/MyDrive/Hands-On-Data-Analysis-with-Pandas-2nd-edition

# %% [markdown]
# # task 1

# %%
import pandas as pd

# %%
data = pd.read_csv("ch_02/data/earthquakes.csv")

# %%
data.head(2)
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt   gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN  85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN  79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
#
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
#
#                                         types     tz        updated  \
# 0  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1  ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
#
#                                                  url
# ...

# %%
data.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %%
data.loc[3:10,['mag', 'magType', 'type']]
# Out:
#      mag magType        type
# 3   0.44      ml  earthquake
# 4   2.16      md  earthquake
# 5   2.61      md  earthquake
# 6   1.70      ml  earthquake
# 7   1.13      md  earthquake
# 8   0.92      md  earthquake
# 9   4.70      mb  earthquake
# 10  0.50      ml  earthquake

# %%
data.loc[(data.place.str.contains("Arizona")),['mag', 'magType', 'type']]
# Out:
#        mag magType        type
# 1062  1.23      ml  earthquake
# 3965  0.94      md  earthquake

# %%
data.mag.nlargest(10, keep='all')
# Out:
# 5263    7.5
# 837     7.0
# 118     6.7
# 4363    6.7
# 799     6.5
# 816     6.2
# 838     6.1
# 5323    6.1
# 862     6.0
# 1267    6.0
# 3699    6.0
# 9211    6.0
# Name: mag, dtype: float64

# %%
data.nlargest(10,['mag'])
# Out:
#       alert  cdi      code                                             detail  \
# 5263    red  8.4  1000h3p4  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 837   green  4.1  1000haa3  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 118   green  NaN  1000hbkz  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4363  green  2.2  1000h4l1  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 799   green  NaN  1000hacw  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 816   green  NaN  1000habl  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 838   green  NaN  1000ha9t  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 5323  green  NaN  1000h3mf  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 862   green  4.3  1000ha6q  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1267  green  NaN  1000h97j  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin   felt   gap                                 ids  mag magType  \
# ...

# %% [markdown]
# # task2

# %% [markdown]
# Tasks for today 2-Try to pop mag and magTypevariables one at a time with name mag, and magType. (use .pop function)-Concatenate mag and magTypevariables and define a new DataFrameusing .concatfunction

# %%
del data['alert']

# %%
mag = data.pop('mag')
magtype = data.pop('magType')

# %%
newdata = pd.concat([mag,magtype])
newdata
# Out:
# 0       1.35
# 1       1.29
# 2       3.42
# 3       0.44
# 4       2.16
#         ...
# 9327      md
# 9328      ml
# 9329      md
# 9330      ml
# 9331      ml
# Length: 18664, dtype: object
